# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import cv2
import torch
import numpy as np
import tkinter as tk
from collections import deque
import matplotlib.pyplot as plt
import matplotlib.animation as animation

from depth_anything_v2.depth_anything_v2.dpt import DepthAnythingV2
from helpers_main import detect_moving_clusters, detect_objects_yolo, \
    estimate_depth, vis_yolo, vis_motion, check_alignment, process_alignment_sequence

DEVICE = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
model_configs = {'vitb': {'encoder': 'vitb', 'features': 128, 'out_channels': [96, 192, 384, 768]}}
encoder = 'vitb'

root = tk.Tk()
screen_w, screen_h = root.winfo_screenwidth(), root.winfo_screenheight()
root.destroy()

# %%
yolo_model = torch.hub.load('./yolov5', 'custom',
                        path='./yolov5/runs/train/my_experiment11/weights/best.pt', # 8 11 14
                        source='local')

# Your initialization code
depth_model = DepthAnythingV2(**model_configs[encoder])
depth_model.load_state_dict(torch.load(f'checkpoints/depth_anything_v2_{encoder}.pth', map_location='cpu'))
depth_model = depth_model.to(DEVICE).eval()
# Out:
# YOLOv5  v7.0-430-g459d8bf0 Python-3.12.9 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
def process_video(video_path, yolo_model, motion_params=None, alignment_params=None, save_trajectory=True):
    """
    Process video for motion detection, YOLO detection, and alignment tracking.
    
    Args:
        video_path: Path to video file
        yolo_model: Pre-loaded YOLO model
        motion_params: Dict with motion detection parameters
        alignment_params: Dict with alignment parameters
        enable_live_plot: Boolean to enable live plotting on world map
    
    Returns:
        List of processed sequences with timing and classification data
    """
    
    # Default parameters
    if motion_params is None:
        motion_params = {
            'motion_threshold': 1.0,
            'dbscan_eps': 30,
            'dbscan_min_samples': 3
        }
    
    if alignment_params is None:
        alignment_params = {
            'max_unaligned_frames': 6,  # frames to ignore without alignment
            'max_sequence_duration': 5.0,  # seconds
            'yolo_confidence': 0.25
        }
    
    # Open video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Cannot open video: {video_path}")
    
    # Get video properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Calculate frame buffer size (5 seconds window)
    buffer_size = int(fps * 5)
    frame_buffer = deque(maxlen=buffer_size)
    
    # Initialize tracking variables
    previous_points = None
    alignment_sequence = []  # stores aligned detections
    processed_sequences = []
    
    # Alignment tracking
    is_aligned = False
    alignment_start_time = None
    unaligned_count = 0
    
    frame_count = 0
    
    print(f"Processing video: {video_path}")
    print(f"FPS: {fps}, Total frames: {total_frames}, Buffer size: {buffer_size}")
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        current_time = frame_count / fps
        
        # Add frame to buffer
        frame_buffer.append(frame.copy())
        
        # Need at least 2 frames for motion detection
        if len(frame_buffer) < 2:
            continue
        
        # Run motion detection on current and previous frame
        prev_frame = frame_buffer[-2]
        current_frame = frame_buffer[-1]
        
        motion_boxes, previous_points = detect_moving_clusters(
            prev_frame, current_frame, previous_points,
            motion_threshold=motion_params['motion_threshold'],
            dbscan_eps=motion_params['dbscan_eps'],
            dbscan_min_samples=motion_params['dbscan_min_samples']
        )
        
        # Check if motion detected
        motion_detected = len(motion_boxes) > 0
        alignment_found = False
        
        if motion_detected:
            vis_motion(current_frame, motion_boxes)
            # Run YOLO on current frame
            yolo_detections = detect_objects_yolo(
                current_frame, yolo_model) 
                #confidence_threshold=alignment_params['yolo_confidence'])
            if yolo_detections:
                vis_yolo(current_frame, yolo_detections)
                # Check alignment between motion clusters and YOLO boxes
                alignment_found = check_alignment(motion_boxes, yolo_detections)
                
                if alignment_found:
                    # Store aligned detection
                    detection_data = {
                        'frame': current_frame.copy(),
                        'frame_number': frame_count,
                        'timestamp': current_time,
                        'motion_boxes': motion_boxes,
                        'yolo_detections': yolo_detections,
                        'yolo_box': yolo_detections[0][:4],  # assuming single detection
                        'class_id': yolo_detections[0][5],
                        'class_name': yolo_detections[0][6],
                        'confidence': yolo_detections[0][4]
                    }
                    alignment_sequence.append(detection_data)
            
            
            h, w = current_frame.shape[:2]
            # scale factor to fit inside screen
            scale = min(screen_w / w, screen_h / h)
            new_w, new_h = int(w * scale), int(h * scale)
            resized = cv2.resize(current_frame, (new_w, new_h), interpolation=cv2.INTER_AREA)
                    
            
            cv2.imshow("Detection Results", resized)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        # Handle alignment state changes
        if alignment_found:
            unaligned_count = 0
            if not is_aligned:
                alignment_start_time = current_time
                print(f"Alignment detected at {current_time:.2f}s")
        else:
            if is_aligned:
                unaligned_count += 1
                
                # Check if alignment should end
                time_exceeded = (current_time - alignment_start_time) >= alignment_params['max_sequence_duration']
                frames_exceeded = unaligned_count > alignment_params['max_unaligned_frames']
                
                if time_exceeded or frames_exceeded:
                    # End alignment sequence and process it
                    if len(alignment_sequence) >= 2:
                        sequence_data = process_alignment_sequence(alignment_sequence, fps)
                        processed_sequences.append(alignment_sequence.copy())
                        
                        # Convert to lat/lon and add to trajectory
                        loc_x, loc_y, loc_z = sequence_data['position2_3d_m']
                        new_lat, new_lon = offset_to_latlon(ref_lat, ref_lon, loc_x, loc_y)
                        trajectory_points.append((new_lat, new_lon))
                        print(f"Added trajectory point: ({new_lat:.6f}, {new_lon:.6f})")

                    # Reset alignment tracking
                    is_aligned = False
                    alignment_sequence.clear()
                    unaligned_count = 0
                    alignment_start_time = None
                    
                    reason = "time exceeded" if time_exceeded else "frames exceeded"
                    print(f"Alignment ended at {current_time:.2f}s ({reason})")
    
    # Handle any remaining alignment sequence at end of video
    if len(alignment_sequence) >= 2:
        sequence_data = process_alignment_sequence(alignment_sequence, fps)
        processed_sequences.append(alignment_sequence)
        
        # Convert to lat/lon and add to trajectory
        loc_x, loc_y, loc_z = sequence_data['position2_3d_m']
        new_lat, new_lon = offset_to_latlon(ref_lat, ref_lon, loc_x, loc_y)
        trajectory_points.append((new_lat, new_lon))
        print(f"Final trajectory point: ({new_lat:.6f}, {new_lon:.6f})")
        
        print("Final alignment sequence processed")
    
    cap.release()
    cv2.destroyAllWindows()  # This closes all OpenCV windows
    
    # Create and save trajectory plot
    if save_trajectory and trajectory_points:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        plot_filename = f"trajectory_map_{timestamp}.png"
        create_trajectory_plot(trajectory_points, plot_filename)
    elif save_trajectory:
        print("No trajectory points found to plot")
    
    print(f"Video processing complete. Found {len(processed_sequences)} sequences.")
    if trajectory_points:
        print(f"Collected {len(trajectory_points)} trajectory points")
    
    return processed_sequences

# %%
# Process video and save trajectory plot
video_path = './media/2.mp4'
processed_sequences = process_video(video_path, yolo_model, save_trajectory=True)
# Out:
# Processing video: ./media/2.mp4
# FPS: 60.0, Total frames: 565, Buffer size: 300
# Alignment detected at 0.03s
# Alignment detected at 0.05s
# Alignment detected at 0.07s
# Alignment detected at 0.08s
# Alignment detected at 0.10s
# Alignment detected at 0.12s
# Alignment detected at 0.13s
# Alignment detected at 0.15s
# Alignment detected at 0.17s
# Alignment detected at 0.18s
# Alignment detected at 0.20s
# Alignment detected at 0.22s
# Alignment detected at 0.23s
# Alignment detected at 0.25s
# Alignment detected at 0.27s
# Alignment detected at 0.28s
# Alignment detected at 0.30s
# Alignment detected at 0.32s
# Alignment detected at 0.33s
# Alignment detected at 0.35s
# Alignment detected at 0.37s
# Alignment detected at 0.38s
# Alignment detected at 0.40s
# Alignment detected at 0.42s
# Alignment detected at 0.43s
# Alignment detected at 0.45s
# Alignment detected at 0.47s
# Alignment detected at 0.48s
# Alignment detected at 0.50s
# Alignment detected at 0.52s
# Alignment detected at 0.53s
# Alignment detected at 0.55s
# Alignment detected at 0.57s
# Alignment detected at 0.58s
# Alignment detected at 0.60s
# Alignment detected at 0.62s
# Alignment detected at 0.63s
# Alignment detected at 0.65s
# Alignment detected at 0.67s
# Alignment detected at 0.68s
# Alignment detected at 0.70s
# Alignment detected at 0.72s
# Alignment detected at 0.73s
# Alignment detected at 0.75s
# Alignment detected at 0.77s
# Alignment detected at 0.78s
# Alignment detected at 0.80s
# Alignment detected at 0.82s
# Alignment detected at 0.83s
# Alignment detected at 0.85s
# Alignment detected at 0.87s
# Alignment detected at 0.88s
# Alignment detected at 0.90s
# Alignment detected at 0.92s
# Alignment detected at 0.93s
# Alignment detected at 0.95s
# Alignment detected at 0.97s
# Alignment detected at 0.98s
# Alignment detected at 1.00s
# Alignment detected at 1.02s
# Alignment detected at 1.03s
# Alignment detected at 1.05s
# Alignment detected at 1.07s
# Alignment detected at 1.08s
# Alignment detected at 1.10s
# Alignment detected at 1.12s
# Alignment detected at 1.13s
# Alignment detected at 1.15s
# Alignment detected at 1.17s
# Alignment detected at 1.18s
# Alignment detected at 1.20s
# Alignment detected at 1.22s
# Alignment detected at 1.23s
# Alignment detected at 1.25s
# Alignment detected at 1.27s
# Alignment detected at 1.28s
# Alignment detected at 1.30s
# Alignment detected at 1.32s
# Alignment detected at 1.33s
# Alignment detected at 1.35s
# Alignment detected at 1.37s
# Alignment detected at 1.38s
# Alignment detected at 1.40s
# Alignment detected at 1.42s
# Alignment detected at 1.43s
# Alignment detected at 1.45s
# Alignment detected at 1.47s
# Alignment detected at 1.48s
# Alignment detected at 1.50s
# Alignment detected at 1.52s
# Alignment detected at 1.53s
# Alignment detected at 1.55s
# Alignment detected at 1.57s
# Alignment detected at 1.58s
# Alignment detected at 1.60s
# Alignment detected at 1.62s
# Alignment detected at 1.63s
# Alignment detected at 1.65s
# Alignment detected at 1.67s
# Alignment detected at 1.68s
# Alignment detected at 1.70s
# Alignment detected at 1.72s
# Alignment detected at 1.73s
# Alignment detected at 1.75s
# Alignment detected at 1.77s
# Alignment detected at 1.78s
# Alignment detected at 1.80s
# Alignment detected at 1.82s
# Alignment detected at 1.83s
# Alignment detected at 1.85s
# Alignment detected at 1.87s
# Alignment detected at 1.88s
# Alignment detected at 1.90s
# Alignment detected at 1.92s
# Alignment detected at 1.93s
# Alignment detected at 1.95s
# Alignment detected at 1.97s
# Alignment detected at 1.98s
# Alignment detected at 2.00s
# Alignment detected at 2.02s
# Alignment detected at 2.03s
# Alignment detected at 2.05s
# Alignment detected at 2.07s
# Alignment detected at 2.08s
# Alignment detected at 2.10s
# Alignment detected at 2.12s
# Alignment detected at 2.13s
# Alignment detected at 2.15s
# Alignment detected at 2.17s
# Alignment detected at 2.18s
# Alignment detected at 2.20s
# Alignment detected at 2.22s
# Alignment detected at 2.23s
# Alignment detected at 2.25s
# Alignment detected at 2.27s
# Alignment detected at 2.28s
# Alignment detected at 2.30s
# Alignment detected at 2.32s
# Alignment detected at 2.33s
# Alignment detected at 2.35s
# Alignment detected at 2.37s
# Alignment detected at 2.38s
# Alignment detected at 2.40s
# Alignment detected at 2.42s
# Alignment detected at 2.43s
# Alignment detected at 2.45s
# Alignment detected at 2.47s
# Alignment detected at 2.48s
# Alignment detected at 2.50s
# Alignment detected at 2.52s
# Alignment detected at 2.53s
# Alignment detected at 2.55s
# Alignment detected at 2.57s
# Alignment detected at 2.58s
# Alignment detected at 2.60s
# Alignment detected at 2.62s
# Alignment detected at 2.63s
# Alignment detected at 2.65s
# Alignment detected at 2.67s
# Alignment detected at 2.68s
# Alignment detected at 2.70s
# Alignment detected at 2.72s
# Alignment detected at 2.73s
# Alignment detected at 2.75s
# Alignment detected at 2.77s
# Alignment detected at 2.78s
# Alignment detected at 2.80s
# Alignment detected at 2.82s
# Alignment detected at 2.83s
# Alignment detected at 2.85s
# Alignment detected at 2.87s
# Alignment detected at 2.88s
# Alignment detected at 2.90s
# Alignment detected at 2.92s
# Alignment detected at 2.93s
# Alignment detected at 2.95s
# Alignment detected at 2.97s
# Alignment detected at 2.98s
# Alignment detected at 3.00s
# Alignment detected at 3.02s
# Alignment detected at 3.03s
# Alignment detected at 3.05s
# Alignment detected at 3.07s
# Alignment detected at 3.08s
# Alignment detected at 3.10s
# Alignment detected at 3.12s
# Alignment detected at 3.13s
# Alignment detected at 3.15s
# Alignment detected at 3.17s
# Alignment detected at 3.18s
# Alignment detected at 3.20s
# Alignment detected at 3.22s
# Alignment detected at 3.23s
# Alignment detected at 3.25s
# Alignment detected at 3.27s
# Alignment detected at 3.28s
# Alignment detected at 3.30s
# Alignment detected at 3.32s
# Alignment detected at 3.33s
# Alignment detected at 3.35s
# Alignment detected at 3.37s
# Alignment detected at 3.38s
# Alignment detected at 3.40s
# Alignment detected at 3.42s
# Alignment detected at 3.43s
# Alignment detected at 3.45s
# Alignment detected at 3.47s
# Alignment detected at 3.48s
# Alignment detected at 3.50s
# Alignment detected at 3.52s
# Alignment detected at 3.53s
# Alignment detected at 3.55s
# Alignment detected at 3.57s
# Alignment detected at 3.58s
# Alignment detected at 3.60s
# Alignment detected at 3.62s
# Alignment detected at 3.63s
# Alignment detected at 3.65s
# Alignment detected at 3.67s
# Alignment detected at 3.68s
# Alignment detected at 3.70s
# Alignment detected at 3.72s
# Alignment detected at 3.73s
# Alignment detected at 3.75s
# Alignment detected at 3.77s
# Alignment detected at 3.78s
# Alignment detected at 3.80s
# Alignment detected at 3.82s
# Alignment detected at 3.83s
# Alignment detected at 3.85s
# Alignment detected at 3.87s
# Alignment detected at 3.88s
# Alignment detected at 3.90s
# Alignment detected at 3.92s
# Alignment detected at 3.93s
# Alignment detected at 3.95s
# Alignment detected at 3.97s
# Alignment detected at 3.98s
# Alignment detected at 4.00s
# Alignment detected at 4.02s
# Alignment detected at 4.03s
# Alignment detected at 4.05s
# Alignment detected at 4.07s
# Alignment detected at 4.08s
# Alignment detected at 4.10s
# Alignment detected at 4.12s
# Alignment detected at 4.13s
# Alignment detected at 4.15s
# Alignment detected at 4.17s
# Alignment detected at 4.18s
# Alignment detected at 4.20s
# Alignment detected at 4.22s
# Alignment detected at 4.23s
# Alignment detected at 4.25s
# Alignment detected at 4.27s
# Alignment detected at 4.28s
# Alignment detected at 4.30s
# Alignment detected at 4.32s
# Alignment detected at 4.33s
# Alignment detected at 4.35s
# Alignment detected at 4.37s
# Alignment detected at 4.38s
# Alignment detected at 4.40s
# Alignment detected at 4.42s
# Alignment detected at 4.43s
# Alignment detected at 4.45s
# Alignment detected at 4.47s
# Alignment detected at 4.48s
# Alignment detected at 4.50s
# Alignment detected at 4.52s
# Alignment detected at 4.53s
# Alignment detected at 4.55s
# Alignment detected at 4.57s
# Alignment detected at 4.58s
# Alignment detected at 4.60s
# Alignment detected at 4.62s
# Alignment detected at 4.63s
# Alignment detected at 4.65s
# Alignment detected at 4.67s
# Alignment detected at 4.68s
# Alignment detected at 4.70s
# Alignment detected at 4.72s
# Alignment detected at 4.73s
# Alignment detected at 4.75s
# Alignment detected at 4.77s
# Alignment detected at 4.78s
# Alignment detected at 4.80s
# Alignment detected at 4.82s
# Alignment detected at 4.83s
# Alignment detected at 4.85s
# Alignment detected at 4.87s
# Alignment detected at 4.88s
# Alignment detected at 4.90s
# Alignment detected at 4.92s
# Alignment detected at 4.93s
# Alignment detected at 4.95s
# Alignment detected at 4.97s
# Alignment detected at 4.98s
# Alignment detected at 5.00s
# Alignment detected at 5.02s
# Alignment detected at 5.03s
# Alignment detected at 5.05s
# Alignment detected at 5.07s
# Alignment detected at 5.08s
# Alignment detected at 5.10s
# Alignment detected at 5.12s
# Alignment detected at 5.13s
# Alignment detected at 5.15s
# Alignment detected at 5.17s
# Alignment detected at 5.18s
# Alignment detected at 5.20s
# Alignment detected at 5.22s
# Alignment detected at 5.23s
# Alignment detected at 5.25s
# Alignment detected at 5.27s
# Alignment detected at 5.28s
# Alignment detected at 5.30s
# Alignment detected at 5.32s
# Alignment detected at 5.33s
# Alignment detected at 5.35s
# Alignment detected at 5.37s
# Alignment detected at 5.38s
# Alignment detected at 5.40s
# Alignment detected at 5.42s
# Alignment detected at 5.43s
# Alignment detected at 5.45s
# Alignment detected at 5.47s
# Alignment detected at 5.48s
# Alignment detected at 5.50s
# Alignment detected at 5.52s
# Alignment detected at 5.53s
# Alignment detected at 5.55s
# Alignment detected at 5.57s
# Alignment detected at 5.58s
# Alignment detected at 5.60s
# Alignment detected at 5.62s
# Alignment detected at 5.63s
# Alignment detected at 5.65s
# Alignment detected at 5.67s
# Alignment detected at 5.68s
# Alignment detected at 5.70s
# Alignment detected at 5.72s
# Alignment detected at 5.73s
# Alignment detected at 5.75s
# Alignment detected at 5.77s
# Alignment detected at 5.78s
# Alignment detected at 5.80s
# Alignment detected at 5.82s
# Alignment detected at 5.83s
# Alignment detected at 5.85s
# Alignment detected at 5.87s
# Alignment detected at 5.88s
# Alignment detected at 5.90s
# Alignment detected at 5.92s
# Alignment detected at 5.93s
# Alignment detected at 5.95s
# Alignment detected at 5.97s
# Alignment detected at 5.98s
# Alignment detected at 6.00s
# Alignment detected at 6.02s
# Alignment detected at 6.03s
# Alignment detected at 6.05s
# Alignment detected at 6.07s
# Alignment detected at 6.08s
# Alignment detected at 6.10s
# Alignment detected at 6.12s
# Alignment detected at 6.13s
# Alignment detected at 6.15s
# Alignment detected at 6.17s
# Alignment detected at 6.18s
# Alignment detected at 6.20s
# Alignment detected at 6.22s
# Alignment detected at 6.23s
# Alignment detected at 6.25s
# Alignment detected at 6.27s
# Alignment detected at 6.28s
# Alignment detected at 6.30s
# Alignment detected at 6.32s
# Alignment detected at 6.33s
# Alignment detected at 6.35s
# Alignment detected at 6.37s
# Alignment detected at 6.38s
# Alignment detected at 6.40s
# Alignment detected at 6.42s
# Alignment detected at 6.43s
# Alignment detected at 6.45s
# Alignment detected at 6.47s
# Alignment detected at 6.48s
# Alignment detected at 6.50s
# Alignment detected at 6.52s
# Alignment detected at 6.53s
# Alignment detected at 6.55s
# Alignment detected at 6.57s
# Alignment detected at 6.58s
# Alignment detected at 6.60s
# Alignment detected at 6.62s
# Alignment detected at 6.63s
# Alignment detected at 6.65s
# Alignment detected at 6.67s
# Alignment detected at 6.68s
# Alignment detected at 6.70s
# Alignment detected at 6.72s
# Alignment detected at 6.73s
# Alignment detected at 6.75s
# Alignment detected at 6.77s
# Alignment detected at 6.78s
# Alignment detected at 6.80s
# Alignment detected at 6.82s
# Alignment detected at 6.83s
# Alignment detected at 6.85s
# Alignment detected at 6.87s
# Alignment detected at 6.88s
# Alignment detected at 6.90s
# Alignment detected at 6.92s
# Alignment detected at 6.93s
# Alignment detected at 6.98s
# Alignment detected at 7.00s
# Alignment detected at 7.02s
# Alignment detected at 7.03s
# Alignment detected at 7.05s
# Alignment detected at 8.40s
# Alignment detected at 8.42s
# Alignment detected at 8.52s
# Alignment detected at 8.65s
# Alignment detected at 9.20s
# Alignment detected at 9.22s
# Alignment detected at 9.23s
# Alignment detected at 9.25s
# Alignment detected at 9.27s
# Alignment detected at 9.28s
# Processing sequence: plane (class 1)
# Duration: 9.25s
# Frames: 430
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 video_path = './media/2.mp4'
# ----> 2 processed_sequences = process_video(video_path, yolo_model, enable_live_plot=True)
#
# Cell In[49], line 164, in process_video(video_path, yolo_model, motion_params, alignment_params, enable_live_plot, save_plots)
#     162 # Handle any remaining alignment sequence at end of video
#     163 if len(alignment_sequence) >= 2:
# --> 164     sequence_data = process_alignment_sequence(alignment_sequence, fps)
#     165     processed_sequences.append(alignment_sequence)
#     167     # Save final plot if enabled
#
# File d:\start2025\helpers_main.py:385, in process_alignment_sequence(alignment_sequence, fps)
#     382     return sequence_data
#     384 if class_id == 1:
# --> 385     speed_data = yolo_plane_3d(start_detection, end_detection, fps)
#     386     sequence_data = {
#     387         'class_id': class_id,
#     388         'class_name': class_name,
#    (...)    394         'all_detections': alignment_sequence
#     395     }
#     396     # Call the arbitrary feed_store function (to be implemented)
#
# File d:\start2025\helpers_main.py:283, in yolo_plane_3d(box1, box2, timestamp, plane_length_m, plane_wingspan_m, focal_length_mm, sensor_width_mm, image_width_px, image_height_px)
#     280 f_px = focal_length_mm * (image_width_px / sensor_width_mm)
#     282 # Frame 1
# --> 283 cx1, cy1, long1, short1 = box_center_and_sides(box1)
#     284 # Scale factor: use the longer side to estimate distance
#     285 z1_long = f_px * plane_length_m / long1
#
# File d:\start2025\helpers_main.py:270, in yolo_plane_3d.<locals>.box_center_and_sides(box)
#     269 def box_center_and_sides(box):
# --> 270     x1, y1, x2, y2 = box
#     271     center_x = (x1 + x2) / 2
#     272     center_y = (y1 + y2) / 2
#
# ValueError: too many values to unpack (expected 4)

# %%
# Simple trajectory plotting on world map
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime

# Reference location (your fixed point)
ref_lat, ref_lon = 46.948, 7.447

def offset_to_latlon(lat0, lon0, dx, dy):
    """
    Convert local offsets (dx east, dy north) in meters to lat/lon coordinates.
    """
    # meters per degree
    m_per_deg_lat = 111320.0
    m_per_deg_lon = 111320.0 * np.cos(np.radians(lat0))
    
    new_lat = lat0 + (dy / m_per_deg_lat)
    new_lon = lon0 + (dx / m_per_deg_lon)
    return new_lat, new_lon

def create_trajectory_plot(trajectory_points, save_path='trajectory_map.png'):
    """
    Create a simple plot showing stationary reference point and moving trajectory.
    
    Args:
        trajectory_points: List of (lat, lon) tuples
        save_path: Path to save the plot
    """
    plt.figure(figsize=(12, 8))
    
    # Plot reference point (stationary)
    plt.plot(ref_lon, ref_lat, 'ro', markersize=15, label='Reference Point (Stationary)', 
             markeredgecolor='darkred', markeredgewidth=2)
    
    # Plot trajectory if we have points
    if trajectory_points:
        lons, lats = zip(*trajectory_points)
        
        # Plot trajectory line
        plt.plot(lons, lats, 'b-', linewidth=3, alpha=0.7, label='Object Trajectory')
        
        # Plot trajectory points
        plt.plot(lons, lats, 'bo', markersize=6, alpha=0.8, label='Detection Points')
        
        # Highlight start and end points
        plt.plot(lons[0], lats[0], 'gs', markersize=12, label='Start', markeredgecolor='darkgreen')
        plt.plot(lons[-1], lats[-1], 'rs', markersize=12, label='End', markeredgecolor='darkred')
        
        # Set bounds around trajectory
        margin = 0.002
        plt.xlim(min(lons) - margin, max(lons) + margin)
        plt.ylim(min(lats) - margin, max(lats) + margin)
    else:
        # Just show reference point with some margin
        margin = 0.01
        plt.xlim(ref_lon - margin, ref_lon + margin)
        plt.ylim(ref_lat - margin, ref_lat + margin)
    
    # Styling
    plt.xlabel('Longitude', fontsize=12)
    plt.ylabel('Latitude', fontsize=12)
    plt.title('Object Tracking on World Map', fontsize=16, fontweight='bold')
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=11)
    
    # Save the plot
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    plt.show()
    
    print(f"Trajectory plot saved to: {save_path}")
    return save_path

# Global list to store trajectory points
trajectory_points = []

print("Trajectory plotting functions ready!")
print("Reference point: ({:.6f}, {:.6f})".format(ref_lat, ref_lon))

# %%
# Test the trajectory plotting with sample data
print("Testing trajectory plotting...")

# Clear any existing points
trajectory_points.clear()

# Add some sample trajectory points
sample_points = [
    (0, 0),      # Start at reference
    (10, 5),     # Move northeast
    (20, 10),    # Continue northeast  
    (15, 15),    # Move north
    (5, 20),     # Move northwest
    (-5, 15),    # Move west
    (-10, 10),   # Move southwest
    (0, 5),      # Move back towards center
]

for dx, dy in sample_points:
    lat, lon = offset_to_latlon(ref_lat, ref_lon, dx, dy)
    trajectory_points.append((lat, lon))

print(f"Created {len(trajectory_points)} sample trajectory points")

# Create the plot
create_trajectory_plot(trajectory_points, 'sample_trajectory_map.png')
